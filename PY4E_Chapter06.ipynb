# %%
#Exercise 6.1: Create while loop to iterate through word from last letter to first. 

var = "pineapple"
#Take length of variable and subtract 1 to get max index, set max index as starting value
index = len(var) - 1

while index >= 0:
    letter = var[index]
    print(letter)
    index = index - 1
# Out:
# e
# l
# p
# p
# a
# e
# n
# i
# p

# %%
#Exercise 6.3: Write a counter that counts the times a letter appears in a word and generalize it in a function so string and letters are arguments 

'''
    #Experiment with inputs
    def count_input():

        word = input("What is the word?")
        letter = input("Which letter?")
        count = 0

        for iteration in word:
            if iteration == letter:
                count = count + 1
        print("The letter" + " " + "'" + str(letter) + "'"  + " " + "appears" + " " + str(count) + " " + "times in the word" + " " + "'" + str(word) + "'")
   ''' 
def count(x, y):

    x = word
    y = letter
    counting = 0
    
    for i in x:
        if i == y:
            counting = counting + 1
    print(counting)
    
count("banana", "a")
# Out:
# 3

# %%
#Exercise 6.4: Write invocation of method count to find the number of times "a" appears in "banana"

word = "banana"

word.count("a")
# Out:
# 3

# %%
#Exercise 6.5: Use find and slicing to find part after colon and use float to convert string.

str = 'X-DSPAM-Confidence:0.8475'

startpos = str.find(":")

#Starting index + 1 to find string after colon:
val = str[startpos + 1 :]
print(float(val))
# Out:
# 0.8475

# %%
#Exercise 6.6, practicing with some methods

str = " het eksamen vindt plaats op maandag "

newstr = str.strip()
print(newstr)

newstr = newstr.replace("ks", "x")
print(newstr)

highest = newstr.rfind("a")
print(highest)

lowest = newstr.find("a")
print(lowest)
# Out:
# het eksamen vindt plaats op maandag
# het examen vindt plaats op maandag
# 32
# 6
